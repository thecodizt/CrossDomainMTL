# %%
import pandas as pd

# %%
metadata = pd.read_csv('../CSV/cross-sectional-data.csv')

metadata
# Out:
#     Unnamed: 0                                 site_id  season_start_month  \
# 0            0           hungry_horse_reservoir_inflow                   4
# 1            1                        snake_r_nr_heise                   4
# 2            2                 pueblo_reservoir_inflow                   4
# 3            3                  sweetwater_r_nr_alcova                   4
# 4            4                    missouri_r_at_toston                   4
# 5            5                     animas_r_at_durango                   4
# 6            6                      yampa_r_nr_maybell                   4
# 7            7                  libby_reservoir_inflow                   4
# 8            8                        boise_r_nr_boise                   4
# 9            9          green_r_bl_howard_a_hanson_dam                   4
# 10          10            taylor_park_reservoir_inflow                   4
# ...

# %%
metadata.isna().sum()
# Out:
# Unnamed: 0            0
# site_id               0
# season_start_month    0
# season_end_month      0
# elevation             0
# latitude              0
# longitude             0
# drainage_area         1
# usgs_id               1
# usgs_name             1
# nrcs_id               4
# nrcs_name             4
# rfc_id                2
# rfc_name              2
# rfc                   2
# area                  0
# geometry              0
# name                  0
# location              0
# dtype: int64

# %%
USGS_IDs = metadata['usgs_id'].unique()

USGS_IDs = [int(x) for x in list(USGS_IDs)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/devarajag/Papers/CrossDomainMTL/Data/USGSStreamFlow/collector.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/devarajag/Papers/CrossDomainMTL/Data/USGSStreamFlow/collector.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> USGS_IDs = metadata['usgs_id'].unique()
# ----> <a href='vscode-notebook-cell:/Users/devarajag/Papers/CrossDomainMTL/Data/USGSStreamFlow/collector.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> USGS_IDs = [int(x) for x in list(USGS_IDs)]
#
# /Users/devarajag/Papers/CrossDomainMTL/Data/USGSStreamFlow/collector.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/devarajag/Papers/CrossDomainMTL/Data/USGSStreamFlow/collector.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> USGS_IDs = metadata['usgs_id'].unique()
# ...
